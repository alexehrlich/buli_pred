# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/interim/matches_combined.csv', index_col=0)

buli_df = df[df['comp'] == 'Bundesliga']
buli_played_df = buli_df[buli_df['result_home'].notna()]
buli_played_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1836 entries, 23 to 2528
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1836 non-null   object
#  1   season       1836 non-null   int64
#  2   round        1836 non-null   object
#  3   day          1836 non-null   object
#  4   comp         1836 non-null   object
#  5   time         1836 non-null   object
#  6   team_home    1836 non-null   object
#  7   result_home  1836 non-null   object
#  8   goals_home   1836 non-null   float64
#  9   goals_away   1836 non-null   float64
#  10  team_away    1836 non-null   object
#  11  xg_home      1835 non-null   float64
#  12  xg_away      1835 non-null   float64
#  13  poss_home    1836 non-null   float64
#  14  sh_home      1836 non-null   float64
#  15  sot_home     1836 non-null   float64
#  16  dist_home    1833 non-null   float64
#  17  poss_away    1836 non-null   float64
# ...

# %%
# Out:
#             date  season         round  day        comp   time team_home  \
# 1159  2022-03-18    2022  Matchweek 27  Fri  Bundesliga  20:30    Bochum
#
#      result_home  goals_home  goals_away  ... poss_home  sh_home  sot_home  \
# 1159           L         0.0         2.0  ...      51.0     16.0       7.0
#
#       dist_home  poss_away  sh_away  sot_away  dist_away    elo_home  \
# 1159        NaN       49.0      8.0       5.0        NaN  1608.93042
#
#          elo_away
# 1159  1671.092773
#
# [1 rows x 23 columns]
