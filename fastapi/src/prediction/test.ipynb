# %%
import requests
import json

r = requests.get('http://127.0.0.1:8000/predict')
response = r.json()

for match in response.values():
    print(key)
# Out:
# {'team_home': 'Bayern Munich', 'team_away': 'RB Leipzig', 'date': '2025-08-22', 'simple_model_results': {'home_team_win': '73.329254', 'home_team_draw_or_loss': '26.670753'}, 'complex_model_results': {'home_team_win': '74.575325', 'draw': '17.130537', 'away_team_win': '8.2941475'}}
# {'team_home': 'Eint Frankfurt', 'team_away': 'Werder Bremen', 'date': '2025-08-23', 'simple_model_results': {'home_team_win': '52.197838', 'home_team_draw_or_loss': '47.80216'}, 'complex_model_results': {'home_team_win': '48.278347', 'draw': '29.667345', 'away_team_win': '22.054312'}}
# {'team_home': 'Union Berlin', 'team_away': 'Stuttgart', 'date': '2025-08-23', 'simple_model_results': {'home_team_win': '32.60834', 'home_team_draw_or_loss': '67.39166'}, 'complex_model_results': {'home_team_win': '24.642893', 'draw': '29.330769', 'away_team_win': '46.026333'}}
# ...
